# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("OSHack_BankCustomers.csv")

# %%
df.head
# Out:
# <bound method NDFrame.head of       age          job  marital  education default  balance housing loan  \
# 0      56   technician  married    primary      no       63     yes   no
# 1      21       admin.  married   tertiary      no       79     yes   no
# 2      19   management  married  secondary      no     -288     yes  yes
# 3      84      unknown  married   tertiary      no     1279      no   no
# 4      35  blue-collar  married    primary      no       26     yes   no
# ...   ...          ...      ...        ...     ...      ...     ...  ...
# 4994   64      retired   single    primary      no        0     yes   no
# 4995   41  blue-collar  married   tertiary      no      275     yes   no
# 4996   51  blue-collar  married   tertiary      no      874     yes   no
# 4997   38   management  married   tertiary      no      247     yes  yes
# 4998   36   technician  married   tertiary      no     6606     yes   no
#
# ...

# %%
df.describe()
# Out:
#                age       balance          day     duration     campaign  \
# count  4999.000000   4999.000000  4999.000000  4999.000000  4999.000000
# mean     52.570114   1520.555911    16.061812   257.295259     2.959792
# std      22.475941   3722.267462     8.205810   267.646023     3.875744
# min      19.000000  -1771.000000     1.000000     3.000000     1.000000
# 25%      32.000000     95.000000     9.000000   102.000000     1.000000
# 50%      51.000000    488.000000    16.000000   176.000000     2.000000
# 75%      75.000000   1484.000000    21.000000   316.000000     3.000000
# max      85.000000  52432.000000    31.000000  2497.000000    33.000000
#
#        OperatingSystems      Browser       Region  TrafficType
# count       4999.000000  4999.000000  4999.000000  4999.000000
# mean           2.167033     2.591118     3.084617     4.397479
# std            1.020746     2.219103     2.369491     4.295489
# min            1.000000     1.000000     1.000000     1.000000
# ...

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign',
#        'OperatingSystems', 'Browser', 'Region', 'TrafficType', 'Weekend'],
#       dtype='object')

# %%
import seaborn as sns

# Create a DataFrame using your data (assuming you have it loaded)
# df = ...

# Set up a grid of subplots
fig, axes = plt.subplots(3, 3, figsize=(15, 15))

# Create various visualizations for the selected columns

# Age Distribution (Histogram)
sns.histplot(df['age'], kde=True, ax=axes[0, 0])
axes[0, 0].set_title('Age Distribution')

# Job Distribution (Bar Chart)
sns.countplot(data=df, x='job', ax=axes[0, 1])
axes[0, 1].set_title('Job Distribution')
axes[0, 1].tick_params(axis='x', rotation=45)

# Marital Status Distribution (Bar Chart)
sns.countplot(data=df, x='marital', ax=axes[0, 2])
axes[0, 2].set_title('Marital Status Distribution')

# Education Distribution (Bar Chart)
sns.countplot(data=df, x='education', ax=axes[1, 0])
axes[1, 0].set_title('Education Distribution')
axes[1, 0].tick_params(axis='x', rotation=45)

# Default Distribution (Bar Chart)
sns.countplot(data=df, x='default', ax=axes[1, 1])
axes[1, 1].set_title('Default Distribution')

# Balance Distribution (Histogram)
sns.histplot(df['balance'], kde=True, ax=axes[1, 2])
axes[1, 2].set_title('Balance Distribution')

# Housing Loan Distribution (Bar Chart)
sns.countplot(data=df, x='housing', ax=axes[2, 0])
axes[2, 0].set_title('Housing Loan Distribution')

# Personal Loan Distribution (Bar Chart)
sns.countplot(data=df, x='loan', ax=axes[2, 1])
axes[2, 1].set_title('Personal Loan Distribution')

# Contact Method Distribution (Bar Chart)
sns.countplot(data=df, x='contact', ax=axes[2, 2])
axes[2, 2].set_title('Contact Method Distribution')
axes[2, 2].tick_params(axis='x', rotation=45)


# Adjust layout
plt.tight_layout()

# Show the combined plot
plt.show()

# %%
# Create a DataFrame using your data (assuming you have it loaded)
# df = ...

# Set up a single subplot for the scatter plot
fig, ax = plt.subplots(figsize=(10, 6))

# Create the scatter plot with labels and regression line
sns.scatterplot(data=df, x='age', y='balance', ax=ax, alpha=0.5)
sns.regplot(data=df, x='age', y='balance', ax=ax, scatter=False, color='red')

# Define the age intervals
start_age = 10
interval_width = 5
max_age = df['age'].max()
age_intervals = np.arange(start_age, max_age + interval_width, interval_width)

# Set x-axis labels to age intervals
ax.set_xticks(age_intervals)
ax.set_xticklabels([f"{age}-{age+interval_width}" for age in age_intervals])

# Customize the plot appearance
ax.set_title('Age vs. Balance Scatter Plot')
ax.set_xlabel('Age Intervals')
ax.set_ylabel('Balance')
ax.legend(['Regression Line'])

# Improve plot aesthetics
sns.set(style="whitegrid")  # Use a white grid background

# Show the plot
plt.tight_layout()
plt.show()

# %%
from scipy.stats import ttest_ind

# Sample data (replace with your dataset)
data = {
    'age': np.random.randint(20, 60, 1000),
    'job': np.random.choice(['Admin', 'Technician', 'Manager', 'Student', 'Retired'], 1000),
    'marital': np.random.choice(['Married', 'Single', 'Divorced'], 1000),
    'education': np.random.choice(['Primary', 'Secondary', 'Tertiary'], 1000),
    'default': np.random.choice(['Yes', 'No'], 1000),
    'balance': np.random.randint(-500, 5000, 1000),
    'housing': np.random.choice(['Yes', 'No'], 1000),
    'loan': np.random.choice(['Yes', 'No'], 1000),
    'contact': np.random.choice(['Cellular', 'Telephone', 'Unknown'], 1000),
    'day': np.random.randint(1, 31, 1000),
    'month': np.random.choice(['Jan', 'Feb', 'Mar', 'Apr', 'May'], 1000),
    'duration': np.random.randint(10, 1000, 1000),
    'campaign': np.random.randint(1, 10, 1000),
    'OperatingSystems': np.random.randint(1, 5, 1000),
    'Browser': np.random.randint(1, 4, 1000),
    'Region': np.random.choice(['North', 'South', 'East', 'West'], 1000),
    'TrafficType': np.random.randint(1, 10, 1000),
    'Weekend': np.random.choice(['Yes', 'No'], 1000)
}

df = pd.DataFrame(data)

# Step 1: Descriptive Statistics
summary_stats = df.describe()

# Step 2: Data Visualization
plt.figure(figsize=(12, 6))
sns.histplot(df['age'], kde=True)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# Step 3: Correlation Analysis
correlation_matrix = df.select_dtypes(include='number').corr()
print(correlation_matrix)
# Step 4: Frequency Distributions
job_distribution = df['job'].value_counts()
plt.figure(figsize=(12, 6))
sns.barplot(x=job_distribution.index, y=job_distribution.values)
plt.title('Job Distribution')
plt.xlabel('Job')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# Step 5: Grouped Analysis
education_grouped = df.groupby('education')['balance'].mean()
print(education_grouped)

# Step 6: Time-Series Analysis (assuming 'day' and 'month' are time-related)
monthly_balance = df.groupby('month')['balance'].mean()
plt.figure(figsize=(10, 5))
sns.lineplot(data=df, x='month', y='balance')
plt.title('Monthly Balance Trend')
plt.xlabel('Month')
plt.ylabel('Average Balance')
plt.show()

# Step 7: Statistical Testing
group1 = df[df['education'] == 'Primary']['balance']
group2 = df[df['education'] == 'Secondary']['balance']

t_stat, p_value = ttest_ind(group1, group2)
print(f"t-statistic: {t_stat}")
print(f"P-value: {p_value}")
# Out:
#                        age   balance       day  duration  campaign  \
# age               1.000000  0.014811  0.010243  0.017535 -0.014607
# balance           0.014811  1.000000 -0.007534  0.064028  0.031324
# day               0.010243 -0.007534  1.000000 -0.029360 -0.006138
# duration          0.017535  0.064028 -0.029360  1.000000  0.003338
# campaign         -0.014607  0.031324 -0.006138  0.003338  1.000000
# OperatingSystems -0.006839 -0.036833  0.000400 -0.086355 -0.004638
# Browser          -0.052294  0.001960  0.031209 -0.012651  0.009767
# TrafficType      -0.039739  0.013125  0.005690  0.020805  0.027711
#
#                   OperatingSystems   Browser  TrafficType
# age                      -0.006839 -0.052294    -0.039739
# balance                  -0.036833  0.001960     0.013125
# day                       0.000400  0.031209     0.005690
# duration                 -0.086355 -0.012651     0.020805
# campaign                 -0.004638  0.009767     0.027711
# ...
